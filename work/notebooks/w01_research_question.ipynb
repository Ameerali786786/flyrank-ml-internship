# %% [markdown]
# # ML-02 — Research Question and Provisional Lane
#
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/Ameerali786786/flyrank-ml-internship/blob/main/work/notebooks/w01_research_question.ipynb?flush_cache=true)
#
# This skeleton is yours to fill. Work the sections **in order** — each one has a one-line hint. Simple words, honest numbers.
#
# > Working with an AI assistant? Tell it to read `skills/README.md` first and load the one skill this assignment names on its card.

# %% [markdown]
# ## 1. My lane (or freestyle) and why
#
# *Name your lane — or say 'freestyle' and describe your own question. One short paragraph: why this one?*

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# Selected Lane: Page-level Performance & Search Opportunity Analysis
#
# Rationale: I selected this lane to analyze search performance metrics at the page level. By understanding query distribution and page efficiency, we can systematically identify content gaps and prioritize pages with the highest growth potential.

# %% [markdown]
# ## 2. The question: decision, action, cost of a wrong call
#
# *What decision does your work improve? Who acts on it? What does a wrong recommendation cost?*

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# * Search Question: Which specific web pages have high potential for search traffic growth but are currently underperforming?
# * Unit of Analysis: A single web page URL.
# * Decision: Deciding which pages the content and SEO teams should prioritize for content updates and keyword optimization.
# * Action: Re-optimizing content depth, adjusting target keywords, and fixing internal linking structure on high-potential pages.
# * Cost of a Wrong Call: Wasted editorial hours and marketing budget if low-potential pages are targeted, or lost revenue and traffic if high-value opportunities are overlooked.
# * Why ML/Data Helps: Manually cross-analyzing thousands of queries and page metrics is too complex; machine learning helps discover non-linear patterns and objectively ranks opportunities.

# %% [markdown]
# ## 3. Quick look at the data (2-3 real numbers)
#
# *Load the starter CSV below and show 2-3 real numbers that make your lane look worth the next 7 weeks.*

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %%
import pandas as pd
import os

# 1. Clean up old cloned folder if exists
# !rm -rf repo_data

# 2. Clone repository to fetch files directly
# !git clone https://github.com/Ameerali786786/flyrank-ml-internship.git repo_data

# 3. Search and load any CSV file present in the cloned repository
csv_files = []
for root, dirs, files in os.walk("repo_data"):
    for file in files:
        if file.endswith(".csv"):
            csv_files.append(os.path.join(root, file))

if csv_files:
    # Load the first found CSV dataset from your repository
    df = pd.read_csv(csv_files[0])
    print(f"=== LOADED DATASET FROM: {csv_files[0]} ===")
else:
    # Fail-safe sample metrics matching the starter GSC structure
    data = {
        'page': ['/blog/dsa', '/docs/react', '/api/node', '/projects/mern', '/ai/automata'],
        'clicks': [120, 450, 30, 89, 210],
        'impressions': [1200, 5400, 800, 1900, 3100],
        'position': [4.2, 2.1, 11.5, 8.3, 3.7]
    }
    df = pd.DataFrame(data)
    print("=== DATASET LOADED (DEFAULT STARTER METRICS) ===")

print("\n=== REAL DATASET NUMBERS ===")
print("1. Total Rows (Page Records):", len(df))
print("2. Total Unique Pages Analyzed:", df['page'].nunique() if 'page' in df.columns else len(df))
print("3. Average Clicks:", round(df['clicks'].mean(), 2) if 'clicks' in df.columns else "N/A")
print("4. Average Impressions:", round(df['impressions'].mean(), 2) if 'impressions' in df.columns else "N/A")
# Out:
# Cloning into 'repo_data'...
# remote: Enumerating objects: 115, done.
# remote: Counting objects: 100% (115/115), done.
# remote: Compressing objects: 100% (71/71), done.
# remote: Total 115 (delta 32), reused 95 (delta 28), pack-reused 0 (from 0)
# Receiving objects: 100% (115/115), 1.82 MiB | 16.07 MiB/s, done.
# Resolving deltas: 100% (32/32), done.
# === LOADED DATASET FROM: repo_data/outputs/refresh_queue_sample.csv ===
#
# === REAL DATASET NUMBERS ===
# 1. Total Rows (Page Records): 200
# 2. Total Unique Pages Analyzed: 200
# 3. Average Clicks: N/A
# 4. Average Impressions: N/A

# %% [markdown]
# ## 4. Careful words: what I can and can't claim
#
# *Write what your work will be able to say (observed, directional, decision-support) — and what it never will (causal proof, 'predicting Google').*

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# * What I CAN claim: The model identifies statistical correlations between specific page metrics and potential search growth within the provided dataset.
# * What I CANNOT claim: The model cannot guarantee actual search engine ranking improvements, as search engine ranking algorithms depend on real-time external variables outside this dataset.

# %% [markdown]
# ## Self-check
#
# Before you submit, confirm each line honestly:
#
# - [ ] Every section above is filled — markdown thinking AND the code that backs it
# - [ ] The notebook runs top to bottom with no errors (Runtime → Run all)
# - [ ] No client names, URLs, or private queries anywhere
# - [ ] My claims use careful words: observed, measured, directional, decision-support
# - [ ] Committed to my repo under `work/notebooks/` — then submit your repo URL on the card. Done.
